# %%
$L1 = toTropicalPolynomial("min(x0-13,x1+14,x2-1)")*
    toTropicalPolynomial("min(x0-14,x1+7,x2+7)")*
    toTropicalPolynomial("min(x0-10,x1-1,x2+11)")*
    toTropicalPolynomial("min(x0-3,x1+3,x2)")*
    toTropicalPolynomial("min(x0-11,x1+13,x2-2)");

# %%
$T1 = new tropical::Hypersurface<Min>(POLYNOMIAL=>$L);
$T1->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 14:58:29 2025
# T
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>T</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$T1->DUAL_SUBDIVISION->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 14:59:01 2025
# pcom:
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>pcom:</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$L2 = toTropicalPolynomial("min(x0-13,x1+14,x2-1)")*
    toTropicalPolynomial("min(x0-14,x1+7,x2+7)")*
    toTropicalPolynomial("min(x0-10,x1-1,x2+11)")*
    toTropicalPolynomial("min(x0-3,x1+3,x2)")*
    toTropicalPolynomial("min(x0-10,x1+14,x2-4)");
$T2 = new tropical::Hypersurface<Min>(POLYNOMIAL=>$L2);
$T2->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 15:06:19 2025
# T2
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>T2</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$T2->DUAL_SUBDIVISION->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 15:06:27 2025
# pcom:
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>pcom:</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$L3 = toTropicalPolynomial("min(x0-13,x1+14,x2-1)")*
    toTropicalPolynomial("min(x0-14,x1+7,x2+7)")*
    toTropicalPolynomial("min(x0-10,x1-1,x2+11)")*
    toTropicalPolynomial("min(x0-3,x1+3,x2)")*
    toTropicalPolynomial("min(x0-9.5,x1+14.5,x2-5)");
$T3 = new tropical::Hypersurface<Min>(POLYNOMIAL=>$L3);
$T3->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 15:31:21 2025
# T3
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>T3</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$T3->DUAL_SUBDIVISION->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 15:31:38 2025
# pcom:
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>pcom:</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$L4 = toTropicalPolynomial("min(x0-13,x1+14,x2-1)")*
    toTropicalPolynomial("min(x0-14,x1+7,x2+7)")*
    toTropicalPolynomial("min(x0-10,x1-1,x2+11)")*
    toTropicalPolynomial("min(x0-3,x1+3,x2)")*
    toTropicalPolynomial("min(x0-9,x1+15,x2-6)");
$T4 = new tropical::Hypersurface<Min>(POLYNOMIAL=>$L4);
$T4->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 15:11:11 2025
# T4
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>T4</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$T4->DUAL_SUBDIVISION->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 15:14:21 2025
# pcom:
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>pcom:</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$L5 = toTropicalPolynomial("min(x0-13,x1+14,x2-1)")*
    toTropicalPolynomial("min(x0-14,x1+7,x2+7)")*
    toTropicalPolynomial("min(x0-10,x1-1,x2+11)")*
    toTropicalPolynomial("min(x0-3,x1+3,x2)")*
    toTropicalPolynomial("min(x0-8,x1+16,x2-8)");
$T5 = new tropical::Hypersurface<Min>(POLYNOMIAL=>$L5);
$T5->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 15:15:40 2025
# T5
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>T5</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...

# %%
$T5->DUAL_SUBDIVISION->VISUAL;
# Out:
# <!--
# polymake for weis
# Wed Oct 29 15:16:21 2025
# pcom:
# -->
#
#
# <html>
#    <head>
#       <meta charset=utf-8>
#       <title>pcom:</title>
#       <style>
# /*
# // COMMON_CODE_BLOCK_BEGIN
# */
#          html {overflow: scroll;}
#          strong{font-size: 18px;}
#          canvas { z-index: 8; }
#          input[type='radio'] {margin-left:0;}
#          input[type='checkbox'] {margin-right:7px; margin-left: 0px; padding-left:0px;}
#          .group{padding-bottom: 15px;}
#          .settings * {z-index: 11; }
#          .settings{z-index: 10; font-family: Arial, Helvetica, sans-serif; margin-left: 30px; visibility: hidden; width: 14em; height: 96%; border: solid 1px silver; padding: 2px; overflow-y: scroll; box-sizing: border-box; background-color: white; position: absolute;}
#          .indented{margin-left: 20px; margin-top: 10px; padding-bottom: 0px;}
#          .shownObjectsList{overflow: auto; max-width: 150px; max-height: 150px;}
# ...
